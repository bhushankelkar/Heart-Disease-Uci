# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("./heart.csv")
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df=df.rename(columns={"cp":"chest_type"})
df.head()
# Out:
#    age  sex  chest_type  trestbps  chol  fbs  restecg  thalach  exang  \
# 0   63    1           3       145   233    1        0      150      0
# 1   37    1           2       130   250    0        1      187      0
# 2   41    0           1       130   204    0        0      172      0
# 3   56    1           1       120   236    0        1      178      0
# 4   57    0           0       120   354    0        1      163      1
#
#    oldpeak  slope  ca  thal  target
# 0      2.3      0   0     1       1
# 1      3.5      0   0     2       1
# 2      1.4      2   0     2       1
# 3      0.8      2   0     2       1
# 4      0.6      2   0     2       1

# %%
df.tail()
# Out:
#      age  sex  chest_type  trestbps  chol  fbs  restecg  thalach  exang  \
# 298   57    0           0       140   241    0        1      123      1
# 299   45    1           3       110   264    0        1      132      0
# 300   68    1           0       144   193    1        1      141      0
# 301   57    1           0       130   131    0        1      115      1
# 302   57    0           1       130   236    0        0      174      0
#
#      oldpeak  slope  ca  thal  target
# 298      0.2      1   0     3       0
# 299      1.2      1   0     3       0
# 300      3.4      1   2     3       0
# 301      1.2      1   1     3       0
# 302      0.0      1   1     2       0

# %%
df['age'][df['target']==1].head()
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 298    False
# 299    False
# 300    False
# 301    False
# 302    False
# Name: target, Length: 303, dtype: bool

# %%
inp.target.value_counts()
# Out:
# 1    165
# 0    138
# Name: target, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.countplot(x="target", data=inp, palette="bwr")
plt.show()
